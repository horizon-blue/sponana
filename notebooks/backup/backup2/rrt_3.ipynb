# %%
import time
from random import random

import numpy as np
from pydrake.all import (
    DiagramBuilder,
    MeshcatVisualizer,
    MultibodyPlant,
    Parser,
    RigidTransform,
    RollPitchYaw,
    RotationMatrix,
    Simulator,
    SolutionResult,
    Solve,
    StartMeshcat,
)
from pydrake.multibody import inverse_kinematics

from manipulation import running_as_notebook
from manipulation.exercises.trajectories.rrt_planner.robot import (
    ConfigurationSpace,
    Range,
)
from manipulation.exercises.trajectories.rrt_planner.rrt_planning import (
    Problem,
)
from manipulation.meshcat_utils import AddMeshcatTriad
from manipulation.scenarios import MakeManipulationStation
import numpy as np
import random
import math
from pydrake.common import temp_directory
from pydrake.geometry import StartMeshcat
from pydrake.systems.analysis import Simulator
from pydrake.visualization import ModelVisualizer
from pydrake.all import Simulator, StartMeshcat, LogVectorOutput

from manipulation import running_as_notebook
from manipulation.station import MakeHardwareStation, load_scenario
from IPython.display import HTML, display
from matplotlib import pyplot as plt
from pydrake.all import (
    AddMultibodyPlantSceneGraph,
    Box,
    ConnectPlanarSceneGraphVisualizer,
    DiagramBuilder,
    FixedOffsetFrame,
    JointIndex,
    Parser,
    PlanarJoint,
    RandomGenerator,
    RigidTransform,
    RotationMatrix,
    Simulator,
    StartMeshcat,
    UniformlyRandomRotationMatrix,
)

from manipulation import ConfigureParser, running_as_notebook
from manipulation.scenarios import AddShape, ycb
from manipulation.station import MakeHardwareStation, load_scenario
from pydrake.common import temp_directory

# sponana/src/sponana/utils.py
import sponana.utils
from sponana.controller import SpotController
from sponana.debug_logger import DebugLogger
from sponana.perception import (
    add_camera_pose_extractor,
    add_body_pose_extractor,
    BananaSpotter,
)
import sponana.sim

# %%
# Start the visualizer.
meshcat = StartMeshcat()
# Out:
# INFO:drake:Meshcat listening for connections at http://localhost:7008

# %%
# Clean up the Meshcat instance.
meshcat.Delete()
meshcat.DeleteAddedControls()
rng = np.random.default_rng(145)  # this is for python
generator = RandomGenerator(rng.integers(0, 1000))  # this is for c++

add_spot = True
# simulation_time = -1  # run indefinitely until ESC is pressed
simulation_time = -1
debug = True
add_fixed_cameras = False
enable_arm_ik = True  # turn this off if you find the arm too annoying
use_teleop = False

simulator, diagram = sponana.sim.clutter_gen(
    meshcat,
    rng,
    debug=debug,
    simulation_time=simulation_time,
    add_spot=add_spot,
    add_fixed_cameras=add_fixed_cameras,
    enable_arm_ik=enable_arm_ik,
    use_teleop=use_teleop,
)
# Out:
# x_sample [-0.1   0.05]
# y_sample [-2.00000000e-01  2.77555756e-17]
# appended: x_points_append: [0.04999999999999999] y_points_append: [2.7755575615628914e-17]
# dist 0.15
# appended: x_points_append: [0.04999999999999999, -0.1] y_points_append: [2.7755575615628914e-17, 2.7755575615628914e-17]
# dist 0.0
# dist 0.2
# dist 0.25
# appended: x_points_append: [0.04999999999999999, -0.1, 0.04999999999999999] y_points_append: [2.7755575615628914e-17, 2.7755575615628914e-17, -0.19999999999999998]
# x_sample [-0.1   0.05]
# y_sample [-2.00000000e-01  2.77555756e-17]
# appended: x_points_append: [-0.1] y_points_append: [-0.19999999999999998]
# x_sample [-0.1   0.05]
# y_sample [-2.00000000e-01  2.77555756e-17]
# appended: x_points_append: [0.04999999999999999] y_points_append: [2.7755575615628914e-17]
# dist 0.2
# appended: x_points_append: [0.04999999999999999, 0.04999999999999999] y_points_append: [2.7755575615628914e-17, -0.19999999999999998]
# dist 0.15
# dist 0.25
# appended: x_points_append: [0.04999999999999999, 0.04999999999999999, -0.1] y_points_append: [2.7755575615628914e-17, -0.19999999999999998, 2.7755575615628914e-17]
# x_sample [-0.1   0.05]
# y_sample [-2.00000000e-01  2.77555756e-17]
# appended: x_points_append: [0.04999999999999999] y_points_append: [2.7755575615628914e-17]
# dist 0.0
# dist 0.0
# dist 0.2
# appended: x_points_append: [0.04999999999999999, 0.04999999999999999] y_points_append: [2.7755575615628914e-17, -0.19999999999999998]
# dist 0.0
# dist 0.25
# dist 0.15
# appended: x_points_append: [0.04999999999999999, 0.04999999999999999, -0.1] y_points_append: [2.7755575615628914e-17, -0.19999999999999998, -0.19999999999999998]
# [TableSceneSpec(has_banana=False, banana_contact_params=None, n_objects=3, object_type_indices=array([0, 1, 1]), object_contact_params=[(0.04999999999999999, 2.7755575615628914e-17, 4.841921954315102, 0), (-0.1, 2.7755575615628914e-17, 1.657078340818876, 0), (0.04999999999999999, -0.19999999999999998, 5.721221562775121, 0)]), TableSceneSpec(has_banana=True, banana_contact_params=(-0.1, -0.19999999999999998, 1.781642008465248, 2), n_objects=3, object_type_indices=array([1, 0, 1]), object_contact_params=[(0.04999999999999999, 2.7755575615628914e-17, 0.925411991541767, 2), (0.04999999999999999, -0.19999999999999998, 4.075456308009082, 2), (-0.1, 2.7755575615628914e-17, 4.303231926064594, 0)]), TableSceneSpec(has_banana=False, banana_contact_params=None, n_objects=3, object_type_indices=array([5, 1, 5]), object_contact_params=[(0.04999999999999999, 2.7755575615628914e-17, 3.1759528834447694, 0), (0.04999999999999999, -0.19999999999999998, 3.0221099894534897, 2), (-0.1, -0.19999999999999998, 5.086347867217728, 2)])]
# Press Space to log system info
# banana_table_idx 1
# spec[banana_table_idx].has_banana True
# Press Escape to stop the simulation
# ==== LCM Warning ===
# LCM detected that large packets are being received, but the kernel UDP
# receive buffer is very small.  The possibility of dropping packets due to
# insufficient buffer space is very high.
#
# For more information, visit:
#    http://lcm-proj.github.io/lcm/multicast_setup.html
#
# WARNING:drake:Ignoring Meshcat http request for /spot_mat.png
# WARNING:drake:Ignoring Meshcat http request for /spot_mat.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/rarama/Documents/research/sponana/notebooks/rrt_3.ipynb Cell 3 line 1
#      <a href='vscode-notebook-cell:/home/rarama/Documents/research/sponana/notebooks/rrt_3.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a> enable_arm_ik = True  # turn this off if you find the arm too annoying
#      <a href='vscode-notebook-cell:/home/rarama/Documents/research/sponana/notebooks/rrt_3.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a> use_teleop = False
# ---> <a href='vscode-notebook-cell:/home/rarama/Documents/research/sponana/notebooks/rrt_3.ipynb#W2sZmlsZQ%3D%3D?line=14'>15</a> simulator, diagram = sponana.sim.clutter_gen(
#      <a href='vscode-notebook-cell:/home/rarama/Documents/research/sponana/notebooks/rrt_3.ipynb#W2sZmlsZQ%3D%3D?line=15'>16</a>     meshcat,
#      <a href='vscode-notebook-cell:/home/rarama/Documents/research/sponana/notebooks/rrt_3.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a>     rng,
#      <a href='vscode-notebook-cell:/home/rarama/Documents/research/sponana/notebooks/rrt_3.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a>     debug=debug,
#      <a href='vscode-notebook-cell:/home/rarama/Documents/research/sponana/notebooks/rrt_3.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a>     simulation_time=simulation_time,
#      <a href='vscode-notebook-cell:/home/rarama/Documents/research/sponana/notebooks/rrt_3.ipynb#W2sZmlsZQ%3D%3D?line=19'>20</a>     add_spot=add_spot,
#      <a href='vscode-notebook-cell:/home/rarama/Documents/research/sponana/notebooks/rrt_3.ipynb#W2sZmlsZQ%3D%3D?line=20'>21</a>     add_fixed_cameras=add_fixed_cameras,
#      <a href='vscode-notebook-cell:/home/rarama/Documents/research/sponana/notebooks/rrt_3.ipynb#W2sZmlsZQ%3D%3D?line=21'>22</a>     enable_arm_ik=enable_arm_ik,
#      <a href='vscode-notebook-cell:/home/rarama/Documents/research/sponana/notebooks/rrt_3.ipynb#W2sZmlsZQ%3D%3D?line=22'>23</a>     use_teleop=use_teleop,
#      <a href='vscode-notebook-cell:/home/rarama/Documents/research/sponana/notebooks/rrt_3.ipynb#W2sZmlsZQ%3D%3D?line=23'>24</a> )
#
# File ~/Documents/research/sponana/src/sponana/sim.py:338, in clutter_gen(meshcat, rng, add_spot, debug, simulation_time, add_fixed_cameras, enable_arm_ik, table_specs, use_teleop)
#     329 plant.SetFreeBodyPose(
#     330     plant_context,
#     331     plant.get_body(
#    (...)
#     334     banana_pose,
#     335 )
#     337 # Run the simulation
# --> 338 sponana.utils.run_simulation(simulator, meshcat, finish_time=simulation_time)
#     339 return simulator, diagram
#
# File ~/Documents/research/sponana/src/sponana/utils.py:51, in run_simulation(simulator, meshcat, finish_time)
#      49     print("Press Escape to stop the simulation")
#      50     while meshcat.GetButtonClicks("Stop Simulation") < 1:
# ---> 51         simulator.AdvanceTo(simulator.get_context().get_time() + 0.1)
#      52     meshcat.DeleteButton("Stop Simulation")
#      53 else:
#      54     # run similator for a fixed duration and publish recording
#
# File ~/Documents/research/sponana/src/sponana/controller/position_combiner.py:27, in PositionCombiner._combine_position(self, context, output)
#      24 def get_arm_position_input_port(self):
#      25     return self.get_input_port(1)
# ---> 27 def _combine_position(self, context: Context, output: BasicVector):
#      28     base_position = self.get_base_position_input_port().Eval(context)[:3]
#      29     arm_position = self.get_arm_position_input_port().Eval(context)
#
# KeyboardInterrupt:

# %%
context = simulator.get_mutable_context()
station = diagram.GetSubsystemByName("station")
#context = station.GetMyContextFromRoot(context)
scene_graph = station.GetSubsystemByName("scene_graph")
plant = station.GetSubsystemByName("plant")

# %%
#plant_context = plant.GetMyContextFromRoot(context)
#print(plant.GetModelInstanceByName("hi"))
"""
plant_context = plant.GetMyContextFromRoot(context)
print(plant.GetModelInstanceByName("spot"))
idx = plant.GetBodyByName(
    "base_x", plant.GetModelInstanceByName("spot")).index()  # Get this
    # get output port with body_poses
    # then index into it by index -- see get_body_poses_output_port() docs!!
spot_model_instance = plant.GetModelInstanceByName("spot")
print(plant.GetPositionNames(spot_model_instance))
print(plant.num_positions(spot_model_instance))
spot_positions = plant.GetPositions(plant_context, spot_model_instance)
print(spot_positions)
new_rotation = RotationMatrix.MakeZRotation(0.2)
new_pose = RigidTransform(new_rotation,
                          [2, 2, 2])
plant.SetFreeBodyPose(plant_context,
            plant.get_body(
                    plant.GetBodyIndices(
                        plant.GetModelInstanceByName("spot")
                    )[0]
                ),
            new_pose)
"""
"""plant.WeldFrames(plant.world_frame(), plant.GetBodyByName("base_x", "spot").body_frame(), RigidTransform(p=[15, 10, 5]))"""

"""
idx = plant.GetBodyByName(
    "base_x", plant.GetModelInstanceByName("spot")).index()  # Get this
    # get output port with body_poses
    # then index into it by index -- see get_body_poses_output_port() docs!!
print(plant.get_body_poses_output_port().Eval(plant_context)[idx])

idx = plant.GetBodyByName(
    "base_y", plant.GetModelInstanceByName("spot")).index()  # Get this
    # get output port with body_poses
    # then index into it by index -- see get_body_poses_output_port() docs!!
print(plant.get_body_poses_output_port().Eval(plant_context)[idx])
"""
"""
idx = plant.GetBodyByName(
    "base_y", plant.GetModelInstanceByName("spot")).index()  # Get this
    # get output port with body_poses
    # then index into it by index -- see get_body_poses_output_port() docs!!
print(idx)
print(plant.get_body_poses_output_port().Eval(plant_context)[idx])
base_pose = plant.get_body_poses_output_port().Eval(plant_context)[idx].translation()
print("base_pose:", base_pose)
new_pose = RigidTransform(plant.get_body_poses_output_port().Eval(plant_context)[idx].rotation(),
                          [2, 2, 2])
plant.SetFreeBodyPose(plant_context,
            plant.get_body(
                    plant.GetBodyIndices(
                        plant.GetModelInstanceByName("spot")
                    )[1]),
            new_pose)
idx = plant.GetBodyByName(
    "base_y", plant.GetModelInstanceByName("spot")).index()  # Get this
    # get output port with body_poses
    # then index into it by index -- see get_body_poses_output_port() docs!!
print(plant.get_body_poses_output_port().Eval(plant_context)[idx])
"""
"""
##check joint sets
plant_context = plant.GetMyContextFromRoot(context)
print(plant.GetModelInstanceByName("spot"))
idx = plant.GetBodyByName(
    "base_x", plant.GetModelInstanceByName("spot")).index()  # Get this
    # get output port with body_poses
    # then index into it by index -- see get_body_poses_output_port() docs!!
plant.get_body_poses_output_port().Eval(plant_context)[idx]
spot_model_instance = plant.GetModelInstanceByName("spot")
print(plant.GetPositionNames(spot_model_instance))
print(plant.num_positions(spot_model_instance))
spot_positions = plant.GetPositions(plant_context, spot_model_instance)
print(spot_positions)
q_desired = spot_positions
q_spot = [1,1,1]
q_desired[0] = q_spot[0]
q_desired[1] = q_spot[1]
q_desired[2] = q_spot[2]

plant.SetPositions(
            plant_context,
            plant.GetModelInstanceByName("spot"),
            q_desired)

#print("after settings")
spot_positions = plant.GetPositions(plant_context, spot_model_instance)
print("after settings", spot_positions)
"""
# Out:
# '\n##check joint sets\nplant_context = plant.GetMyContextFromRoot(context)\nprint(plant.GetModelInstanceByName("spot"))\nidx = plant.GetBodyByName(\n    "base_x", plant.GetModelInstanceByName("spot")).index()  # Get this\n    # get output port with body_poses\n    # then index into it by index -- see get_body_poses_output_port() docs!!\nplant.get_body_poses_output_port().Eval(plant_context)[idx]\nspot_model_instance = plant.GetModelInstanceByName("spot")\nprint(plant.GetPositionNames(spot_model_instance))\nprint(plant.num_positions(spot_model_instance))\nspot_positions = plant.GetPositions(plant_context, spot_model_instance)\nprint(spot_positions)\nq_desired = spot_positions\nq_spot = [1,1,1]\nq_desired[0] = q_spot[0]\nq_desired[1] = q_spot[1]\nq_desired[2] = q_spot[2]\n\nplant.SetPositions(\n            plant_context,\n            plant.GetModelInstanceByName("spot"),\n            q_desired)\n\n#print("after settings")\nspot_positions = plant.GetPositions(plant_context, spot_model_instance)\nprint("after settings", spot_positions)\n'

# %%
def check_collision_pair_name(pair_name0, pair_name1):
    pair0_is_spot = pair_name0.startswith("spot")
    pair1_is_spot = pair_name1.startswith("spot")
    if pair0_is_spot == False and pair1_is_spot == False:
        return False
    if pair0_is_spot == True and pair1_is_spot == True: 
        return False
    if pair0_is_spot == True and (pair_name1.startswith("table_top") or 
        pair_name1.startswith("back_wall")):
        return True
    if pair1_is_spot == True and (pair_name0.startswith("table_top") or 
        pair_name0.startswith("back_wall")):
        return True
    return False

# %%
def in_collision(plant, scene_graph, context, print_collisions=True, thresh=1e-12):
    plant_context = plant.GetMyContextFromRoot(context)
    sg_context = scene_graph.GetMyContextFromRoot(context)
    query_object = plant.get_geometry_query_input_port().Eval(plant_context)
    inspector = scene_graph.get_query_output_port().Eval(sg_context).inspector()
    pairs = inspector.GetCollisionCandidates()
    dists = []

    for pair in pairs:
        pair_name0 = inspector.GetName(inspector.GetFrameId(pair[0]))
        pair_name1 = inspector.GetName(inspector.GetFrameId(pair[1]))
        
        if check_collision_pair_name(pair_name0, pair_name1) == False:
            continue
        #print("after check",inspector.GetName(inspector.GetFrameId(pair[0])),
        #          inspector.GetName(inspector.GetFrameId(pair[1])))
        dists.append(query_object.ComputeSignedDistancePairClosestPoints(pair[0], pair[1]).distance)
        if dists[-1] < thresh and print_collisions:
            print(inspector.GetName(inspector.GetFrameId(pair[0])),
                  inspector.GetName(inspector.GetFrameId(pair[1])))
    return np.min(dists) < thresh

# %%
collision_check = in_collision(plant, scene_graph,context, print_collisions=True)
print("Check Collision:", collision_check)
# Out:
# Check Collision: False

# %%
def move_spot(q_spot):
    plant_context = plant.GetMyContextFromRoot(context)
    print(plant.GetModelInstanceByName("spot"))
    idx = plant.GetBodyByName(
        "base_x", plant.GetModelInstanceByName("spot")).index()  # Get this
        # get output port with body_poses
        # then index into it by index -- see get_body_poses_output_port() docs!!
    plant.get_body_poses_output_port().Eval(plant_context)[idx]
    spot_model_instance = plant.GetModelInstanceByName("spot")
    print(plant.GetPositionNames(spot_model_instance))
    print(plant.num_positions(spot_model_instance))
    spot_positions = plant.GetPositions(plant_context, spot_model_instance)
    spot_init_positions = np.copy(spot_positions)
    q_desired = np.copy(spot_positions)
    #spot_init_positions = spot_positions
    #print(spot_positions)
    q_desired = spot_positions
    q_desired[0] = q_spot[0]
    q_desired[1] = q_spot[1]
    q_desired[2] = q_spot[2]

    plant.SetPositions(
                plant_context,
                plant.GetModelInstanceByName("spot"),
                q_desired)

    #print("after settings")
    spot_positions = plant.GetPositions(plant_context, spot_model_instance)
    print("after settings", spot_positions)
    return spot_init_positions

# %%
def ExistsCollision(q_spot):
    spot_init_positions = move_spot(q_spot)
    collision_check = in_collision(plant, scene_graph,context, print_collisions=True)
    
    print("Check Collision:", collision_check)
    if collision_check == True: 
        previous_pos = move_spot(spot_init_positions)
    return collision_check

# %%
class SpotProblem(Problem):
    def __init__(
        self,
        q_start: np.array,
        q_goal: np.array):
        nq = 3
        joint_limits = np.zeros((nq, 2))
        """
        for i in range(nq):
            joint = plant.GetJointByName("iiwa_joint_%i" % (i + 1))
            joint_limits[i, 0] = joint.position_lower_limits()
            joint_limits[i, 1] = joint.position_upper_limits()
        """
        joint_limits = np.zeros((nq, 2))
        #x
        joint_limits[0, 0] = -3
        joint_limits[0, 1] = 3
        #y
        joint_limits[1, 0] = -3
        joint_limits[1, 1] = 3
        #z theta
        joint_limits[2, 0] = 0
        joint_limits[2, 1] = 2 * np.pi

        range_list = []
        for joint_limit in joint_limits:
            range_list.append(Range(joint_limit[0], joint_limit[1]))

        def l2_distance(q: tuple):
            sum = 0
            for q_i in q:
                sum += q_i**2
            return np.sqrt(sum)
        max_steps = nq * 1/4 #random max_steps for now
        #max_steps = nq * 1/4
        #max_steps = nq * [np.pi / 180 * 2]  # three degrees
        cspace_spot = ConfigurationSpace(range_list, l2_distance, [max_steps for _ in range_list])

        """
        nq = 10

        joint_limits = np.zeros((nq, 2))
        spot_model_instance = plant.GetModelInstanceByName("spot")
        plant_context = plant.GetMyContextFromRoot(context)
        spot_positions = plant.GetPositions(plant_context, spot_model_instance)
        print("print:", spot_positions)
        #x
        joint_limits[0, 0] = -2
        joint_limits[0, 1] = 2
        #y
        joint_limits[1, 0] = -2
        joint_limits[1, 1] = 2
        #z theta
        joint_limits[2, 0] = 0
        joint_limits[2, 1] = 2 * np.pi

        for i in range(4, 10):
            joint_limits[i, 0] = spot_positions[i]
            joint_limits[i, 1] = spot_positions[i]

        range_list = []
        for joint_limit in joint_limits:
            range_list.append(Range(joint_limit[0], joint_limit[1]))

        def l2_distance(q: tuple):
            sum = 0
            for q_i in q:
                sum += q_i**2
            return np.sqrt(sum)
        max_steps = nq * 1/4 #random max_steps for now
        #max_steps = nq * [np.pi / 180 * 2]  # three degrees
        cspace_spot = ConfigurationSpace(range_list, l2_distance, [max_steps for _ in range_list])
        """
        # Call base class constructor.
        Problem.__init__(
            self,
            x=10,  # not used.
            y=10,  # not used.
            robot=None,  # not used.
            obstacles=None,  # not used.
            start=tuple(q_start),
            goal=tuple(q_goal),
            cspace=cspace_spot,
        )

    def collide(self, configuration):
        collision = ExistsCollision(np.array(configuration))
        return collision

# %%
class TreeNode:
    def __init__(self, value, parent=None):
        self.value = value  # tuple of floats representing a configuration
        self.parent = parent  # another TreeNode
        self.children = []  # list of TreeNodes

# %%
class RRT:
    """
    RRT Tree.
    """

    def __init__(self, root: TreeNode, cspace: ConfigurationSpace):
        self.root = root  # root TreeNode
        self.cspace = cspace  # robot.ConfigurationSpace
        self.size = 1  # int length of path
        self.max_recursion = 1000  # int length of longest possible path

    def add_configuration(self, parent_node, child_value):
        child_node = TreeNode(child_value, parent_node)
        parent_node.children.append(child_node)
        self.size += 1
        return child_node

    # Brute force nearest, handles general distance functions
    def nearest(self, configuration):
        """
        Finds the nearest node by distance to configuration in the
             configuration space.

        Args:
            configuration: tuple of floats representing a configuration of a
                robot

        Returns:
            closest: TreeNode. the closest node in the configuration space
                to configuration
            distance: float. distance from configuration to closest
        """
        assert self.cspace.valid_configuration(configuration)

        def recur(node, depth=0):
            closest, distance = node, self.cspace.distance(
                node.value, configuration
            )
            if depth < self.max_recursion:
                for child in node.children:
                    (child_closest, child_distance) = recur(child, depth + 1)
                    if child_distance < distance:
                        closest = child_closest
                        child_distance = child_distance
            return closest, distance

        return recur(self.root)[0]

# %%
meshcat.Delete()
meshcat.DeleteAddedControls()

base_pose = np.array([1.00000000e+00, 1.50392176e-12, 3.15001955e+00])
q_start = base_pose
q_goal = np.array([-2, -2, 3.15001955e+00])
#q_goal = np.array([0.20894849, -0.47792893, 0.2475])
#q_goal = np.array([0.20894849, -0.47792893, 0.2475])

# %%
spot_problem = SpotProblem(
    q_start=q_start,
    q_goal=q_goal)
# Out:
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [ 1.00000000e+00  1.50392176e-12  3.15001955e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# Check Collision: False
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [-2.00000000e+00 -2.00000000e+00  3.15001955e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# Check Collision: False

# %%
class RRT_tools:
    def __init__(self, problem):
        # rrt is a tree
        self.rrt_tree = RRT(TreeNode(problem.start), problem.cspace)
        problem.rrts = [self.rrt_tree]
        self.problem = problem

    def find_nearest_node_in_RRT_graph(self, q_sample):
        nearest_node = self.rrt_tree.nearest(q_sample)
        return nearest_node

    def sample_node_in_configuration_space(self):
        q_sample = self.problem.cspace.sample()
        return q_sample

    def calc_intermediate_qs_wo_collision(self, q_start, q_end):
        """create more samples by linear interpolation from q_start
        to q_end. Return all samples that are not in collision

        Example interpolated path:
        q_start, qa, qb, (Obstacle), qc , q_end
        returns >>> q_start, qa, qb
        """
        print(f"q start: {q_start}")
        print(f"q end: {q_end}")
        return self.problem.safe_path(q_start, q_end)

    def grow_rrt_tree(self, parent_node, q_sample):
        """
        add q_sample to the rrt tree as a child of the parent node
        returns the rrt tree node generated from q_sample
        """
        child_node = self.rrt_tree.add_configuration(parent_node, q_sample)
        return child_node

    def node_reaches_goal(self, node):
        return node.value == self.problem.goal

    def backup_path_from_node(self, node):
        path = [node.value]
        while node.parent is not None:
            node = node.parent
            path.append(node.value)
        path.reverse()
        return path

# %%
def rrt_planning(problem, max_iterations=1000, prob_sample_q_goal=0.05):
    """
    Input:
        problem (IiwaProblem): instance of a utility class
        max_iterations: the maximum number of samples to be collected
        prob_sample_q_goal: the probability of sampling q_goal

    Output:
        path (list): [q_start, ...., q_goal].
                    Note q's are configurations, not RRT nodes
    """
    """ Input: q_start, q_goal, max_interation, prob_sample_goal
      Output: path

      G.init(q_start)
      for k = 1 to max_interation:
        q_sample ← Generate Random Configuration
        random number ← random()
        if random_number < prob_sample_goal:
            q_sample ← q_goal
        n_near ← Find the nearest node in the tree(q_sample)
        (q_1, q_2, ... q_N) ← Find intermediate q's from n_near to q_sample
        
        // iteratively add the new nodes to the tree to form a new edge
        last_node ← n_near
        for n = 1 to N:
            last_node ← Grow RRT tree (parent_node, q_{n}) 
        
        if last node reaches the goal:
            path ← backup the path recursively
            return path
        
      return None"""
    rrt_tools = RRT_tools(spot_problem)
    q_goal = problem.goal
    q_start = problem.start
    i = 0 
    while i < max_iterations:
        #generate random
        q_sample = rrt_tools.sample_node_in_configuration_space()
        rand_numb = random.random()
        if rand_numb < prob_sample_q_goal:
            q_sample = q_goal
        n_near = rrt_tools.find_nearest_node_in_RRT_graph(q_sample)
        intermediate_qs = rrt_tools.calc_intermediate_qs_wo_collision(n_near.value, q_sample)

        last_node = n_near
        for n in range(len(intermediate_qs)):
            last_node = rrt_tools.grow_rrt_tree(n_near, intermediate_qs[n])

        if rrt_tools.node_reaches_goal(last_node):
            path = rrt_tools.backup_path_from_node(last_node)
            return path
        i +=1
    return None

# %%
path = rrt_planning(spot_problem, 600, 0.05)
# Out:
# q start: (1.0, 1.50392176e-12, 3.15001955)
# q end: (1.8084726673630085, 2.464587702452236, 0.8273832789292257)
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [ 1.00000000e+00  1.50392176e-12  3.15001955e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# Check Collision: False
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [ 1.26949089e+00  8.21529234e-01  2.37580746e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# Check Collision: False
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [ 1.53898178e+00  1.64305847e+00  1.60159537e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# Check Collision: False
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [ 1.80847267e+00  2.46458770e+00  8.27383279e-01 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# Check Collision: False
# q start: (1
+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# table_top6::table_top6_link spot::arm_link_fngr
# table_top6::table_top6_link spot_camera::base
# table_top6::table_top6_link spot::front_left_upper_leg
# table_top6::table_top6_link spot::arm_link_wr0
# table_top6::table_top6_link spot::body
# table_top6::table_top6_link spot::arm_link_wr1
# Check Collision: True
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [-1.55217890e-01  9.59816352e-01  3.05215981e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# q start: (-0.1552178895302534, 0.9598163517529659, 3.0521598084051194)
# q end: (0.39530508440525036, 1.7084346765201506, 3.346128200257369)
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [-1.55217890e-01  9.59816352e-01  3.05215981e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# Check Collision: False
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [ 3.95305084e-01  1.70843468e+00  3.34612820e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# table_top6::table_top6_link spot::front_left_upper_leg
# table_top1::table_top_link spot::front_right_lower_leg
# table_top6::table_top6_link spot::front_left_lower_leg
# table_top6::table_top6_link spot::front_left_lower_leg
# Check Collision: True
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [-1.55217890e-01  9.59816352e-01  3.05215981e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# q start: (1.426244629160666, 1.4287504327484721, 4.694446600185992)
# q end: (2.5677691155476197, 0.6644315136933718, 4.330395832193187)
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [ 1.42624463e+00  1.42875043e+00  4.69444660e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# Check Collision: False
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [ 2.56776912e+00  6.64431514e-01  4.33039583e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# Check Collision: False
# q start: (-0.1552178895302534, 0.9598163517529659, 3.0521598084051194)
# q end: (-2.0, -2.0, 3.15001955)
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [-1.55217890e-01  9.59816352e-01  3.05215981e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# Check Collision: False
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [-7.70145260e-01 -2.67890988e-02  3.08477972e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# back_wall::table_top9_link spot::arm_link_fngr
# back_wall::table_top9_link spot::arm_link_fngr
# table_top0::table_top_link spot::rear_right_lower_leg
# back_wall::table_top9_link spot::arm_link_wr1
# Check Collision: True
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [-1.55217890e-01  9.59816352e-01  3.05215981e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# q start: (-0.1552178895302534, 0.9598163517529659, 3.0521598084051194)
# q end: (-2.453528359396657, -2.2872288367874933, 3.42403946280759)
# ModelInstanceIndex(22)
# ...
# 10
# after settings [ 1.00492596e+00  6.01355704e-01  5.49216595e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# q start: (-0.2066248751284938, -0.8215264637267055, 3.744488470554365)
# q end: (-2.8132682847727164, -2.093320726622925, 3.7695570927928026)
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [-2.06624875e-01 -8.21526464e-01  3.74448847e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# Check Collision: False
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [-1.07550601e+00 -1.24545788e+00  3.75284468e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# back_wall::table_top9_link spot::front_right_upper_leg
# table_top5::table_top5_link spot::front_left_lower_leg
# back_wall::table_top9_link spot::body
# back_wall::table_top9_link spot::arm_link_sh0
# table_top5::table_top5_link spot::front_left_lower_leg
# back_wall::table_top9_link spot::arm_link_sh0
# back_wall::table_top9_link spot::front_right_lower_leg
# back_wall::table_top9_link spot::front_left_upper_leg
# back_wall::table_top9_link spot::arm_link_el1
# back_wall::table_top9_link spot::arm_link_hr0
# table_top5::table_top5_link spot::front_left_upper_leg
# table_top5::table_top5_link spot::body
# Check Collision: True
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [-2.06624875e-01 -8.21526464e-01  3.74448847e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# q start: (2.1294458997784647, 1.4997125179454889, 3.06943544793029)
# q end: (2.188203117532037, 2.0933654959291683, 1.9896002462925912)
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [ 2.12944590e+00  1.49971252e+00  3.06943545e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# Check Collision: False
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [ 2.18820312e+00  2.09336550e+00  1.98960025e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# Check Collision: False
# q start: (2.6777105177508815, 1.2560019013869521, 5.632061460231641)
# q end: (2.5796550887489635, 1.8922695003461332, 5.604307508948669)
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [ 2.67771052e+00  1.25600190e+00  5.63206146e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# Check Collision: False
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [ 2.57965509e+00  1.89226950e+00  5.60430751e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# Check Collision: False
# q start: (-0.2066248751284938, -0.8215264637267055, 3.744488470554365)
# q end: (-2.0018435580364136, -2.1152050033614787, 3.8726918982251926)
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [-2.06624875e-01 -8.21526464e-01  3.74448847e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# Check Collision: False
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [-1.10423422e+00 -1.46836573e+00  3.80859018e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# table_top5::table_top5_link spot::arm_link_hr0
# back_wall::table_top9_link spot::front_right_upper_leg
# back_wall::table_top9_link spot::body
# table_top5::table_top5_link spot::arm_link_el0
# back_wall::table_top9_link spot::arm_link_sh0
# back_wall::table_top9_link spot::front_right_lower_leg
# back_wall::table_top9_link spot::front_left_upper_leg
# table_top5::table_top5_link spot::rear_left_upper_leg
# back_wall::table_top9_link spot::arm_link_el1
# back_wall::table_top9_link spot::arm_link_hr0
# table_top5::table_top5_link spot::body
# table_top5::table_top5_link spot::arm_link_el1
# Check Collision: True
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [-2.06624875e-01 -8.21526464e-01  3.74448847e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# q start: (-0.3887314919555509, 0.7785274754381395, 3.9210235111047362)
# q end: (-0.03125798584117856, 0.37797065570698507, 3.472935295445086)
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [-3.88731492e-01  7.78527475e-01  3.92102351e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# Check Collision: False
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [-3.12579858e-02  3.77970656e-01  3.47293530e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# table_top0::table_top_link spot::front_left_lower_leg
# Check Collision: True
# ModelInstanceIndex(22)
# ['base_x_x', 'base_y_x', 'base_rz_q', 'arm_sh0_q', 'arm_sh1_q', 'arm_el0_q', 'arm_el1_q', 'arm_wr0_q', 'arm_wr1_q', 'arm_f1x_q']
# 10
# after settings [-3.88731492e-01  7.78527475e-01  3.92102351e+00 -1.63362487e-04
#  -3.10083480e+00  3.10063473e+00 -2.63772386e-03  5.04416012e-04
#  -3.58960314e-03  5.18063590e-11]
# q start: (